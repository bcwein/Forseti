# %% [markdown]
# # Synthetic Datasets

# %%
import sys
import os

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from forseti.datasets import datasetgen
import seaborn as sns

sns.set_style('darkgrid')

# %%
a = datasetgen(
    n_samples=40000,
    seperability=0.5,
    informative=True
)

sns.scatterplot(
    x='Feature 3',
    y='Feature 4',
    hue='Race',
    data=a
)
# Out:
# <AxesSubplot:xlabel='Feature 3', ylabel='Feature 4'>

# %%
sns.scatterplot(
    x='Feature 3',
    y='Feature 4',
    hue='Success',
    data=a
)
# Out:
# <AxesSubplot:xlabel='Feature 3', ylabel='Feature 4'>
